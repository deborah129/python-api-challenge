# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from api_keys import g_key

#configure gmap
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
csv_file_df = pd.read_csv("Data.csv")
csv_file_df.head()
# Out:
#       City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Fortuna          20      US  1569548205        77  40.60 -124.16
# 1  Sarkand          99      KZ  1569548205        27  45.41   79.91
# 2  Iqaluit          90      CA  1569548205        80  63.75  -68.52
# 3   Dafeng         100      CN  1569548205        52  33.20  120.46
# 4  Rikitea          39      PF  1569548206        71 -23.12 -134.97
#
#    Max Temp(C)  Wind Speed
# 0        18.33        5.10
# 1        17.64        2.71
# 2         4.00       11.80
# 3        24.54        2.43
# 4        22.14        4.70

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
csv_file_df.dropna()
csv_file_df.head()
# Out:
#       City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Fortuna          20      US  1569548205        77  40.60 -124.16
# 1  Sarkand          99      KZ  1569548205        27  45.41   79.91
# 2  Iqaluit          90      CA  1569548205        80  63.75  -68.52
# 3   Dafeng         100      CN  1569548205        52  33.20  120.46
# 4  Rikitea          39      PF  1569548206        71 -23.12 -134.97
#
#    Max Temp(C)  Wind Speed
# 0        18.33        5.10
# 1        17.64        2.71
# 2         4.00       11.80
# 3        24.54        2.43
# 4        22.14        4.70

# %%
locations = csv_file_df[["Lat", "Lng"]]
new_york_coordinates = (40.75, -74.00)
fig = gmaps.figure(center=new_york_coordinates, zoom_level=2)
heat_layer = gmaps.heatmap_layer(locations, weights=csv_file_df["Humidity"], dissipating=False, max_intensity=10, point_radius=2)

#Add layer
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
chosen_pd = csv_file_df[csv_file_df["Humidity"]<=50]
chosen_pd
# Out:
#                         City  Cloudiness Country        Date  Humidity    Lat  \
# 1                    Sarkand          99      KZ  1569548205        27  45.41
# 14                Tymovskoye           0      RU  1569548207        39  50.85
# 26   San Carlos de Bariloche           0      AR  1569548093        41 -41.13
# 27              Grootfontein           0     NaN  1569548209        33 -19.56
# 30                 Jamestown           0      AU  1569548209        33 -33.21
# 34                     Yumen           0      CN  1569548210        10  40.29
# 40             Mar del Plata         100      AR  1569548211        43 -46.43
# 48                     Bluff           0      AU  1569548212        31 -23.58
# 51                  Cherskiy           3      RU  1569548213        39  68.75
# 54                  Karratha           0      AU  1569548213        15 -20.74
# 55                 Ilulissat           0      GL  1569548214        35  69.22
# 56               East London           0      ZA  1569548049        17 -33.02
# 59                Codrington           6      AU  1569548214        50 -28.95
# 60                    Nemuro          20      JP  1569548214        42  43.32
# 65                   Chifeng          32      CN  1569548215        21  42.27
# 66                     Kroya          57      ID  1569548215        33  -6.50
# 67       Santiago del Estero           0      AR  1569548216        36 -27.80
# 72                 Busselton          94      AU  1569547962        47 -33.64
# 77                    Harper           1      US  1569548217        45  30.30
# 89                   Birjand           0      IR  1569548219        13  32.86
# 90             West Wendover           1      US  1569548219        25  40.74
# 91                    Yulara           0      AU  1569548219        20 -25.24
# 94                 Carnarvon           0      ZA  1569548196        18 -30.97
# 106                 Luderitz          99     NaN  1569548222        37 -26.65
# 107                Tucumcari           1      US  1569548222        30  35.17
# 113                    Airai           0      TL  1569548223        46  -8.93
# 133                    Arman           1      RU  1569548227        46  59.70
# 140        Riachao das Neves           3      BR  1569548224        30 -11.75
# 151                  Atwater          75      US  1569548229        40  37.35
# 160        Nerchinskiy Zavod           1      RU  1569548231        41  51.31
# ..                       ...         ...     ...         ...       ...    ...
# 353            Central Point           1      US  1569548263        32  42.38
# 358                 La Rioja           0      AR  1569548264        39 -29.41
# 380                     Bafq           0      IR  1569548268        12  31.60
# 381                   Katobu          70      ID  1569548268        44  -4.94
# 383            Alice Springs           0      AU  1569548268        26 -23.70
# 387                     Jalu           0      LY  1569548269        50  29.03
# 420                 Caldwell           1      US  1569548274        35  43.67
# 422                    Vardo           1      US  1569548275        49  39.62
# 423               Hervey Bay          40      AU  1569548275        47 -25.30
# 426                    Digby          33      CA  1569548275         1  44.62
# 435                    Adrar           0      DZ  1569548277         9  27.87
# 439                   Kargil           0      PK  1569548278        43  34.56
# 440                Sar-e Pul           0      AF  1569548278        18  36.22
# 444                   Aranos           0     NaN  1569548279        24 -24.14
# 456               San Rafael          82      AR  1569548281        32 -34.61
# 459                 Flinders           0      AU  1569548281        24 -34.58
# 463                   Kerman           0      IR  1569548282        14  30.29
# 483                   Mehran           0      IR  1569548285        28  33.12
# 492                   Madang           0      CN  1569548287        42  35.32
# 493                   Pishin           0      PK  1569548287        44  30.58
# 503                    Mecca           0      SA  1569548023        14  21.43
# 504                   Beyneu          93      KZ  1569548289        35  45.32
# 507                    Aswan           0      EG  1569548289        17  24.09
# 512               Xiangxiang          36      CN  1569548290        33  27.73
# 520                Katherine           0      AU  1569548291        31 -14.47
# 524                    Herat           0      AF  1569548292        23  34.35
# 529                     Mayo          75      CA  1569548293        36  63.59
# 535               San Angelo           1      US  1569548014        36  31.46
# 541                   Noumea          75      NC  1569548000        42 -22.28
# 549               Baruun-Urt          49      MN  1569548296        25  46.68
#
#         Lng  Max Temp(C)  Wind Speed
# 1     79.91        17.64        2.71
# 14   142.66        15.94        3.06
# 26   -71.31        15.00        2.10
# 27    18.10         8.34        4.25
# 30   138.60        21.84        6.71
# 34    97.04        24.14        2.91
# 40   -67.52        12.84        7.65
# 48   149.07        28.54        3.02
# 51   161.30         4.14        2.80
# 54   116.85        29.74        4.10
# 55   -51.10         4.00        4.60
# 56    27.91        18.14        2.24
# 59   153.24        27.00        4.10
# 60   145.57        19.00        0.50
# 65   118.96        21.94        3.35
# 66   108.06        34.24        3.68
# 67   -64.26        20.04        4.25
# 72   115.35        18.33        2.90
# 77   -99.24        29.00        6.05
# 89    59.22        21.00        6.20
# 90  -114.07        25.00        3.65
# 91   130.99        29.00        2.60
# 94    22.13        10.24        2.32
# 106   15.16        22.00        0.50
# 107 -103.73        27.00        4.60
# 113  125.41        30.24        2.42
# 133  150.17         3.44        3.17
# 140  -44.91        22.14        1.12
# 151 -120.61        30.00        5.70
# 160  119.61        18.24        5.04
# ..      ...          ...         ...
# 353 -122.91        28.00        4.10
# 358  -66.86        16.44        2.40
# 380   55.40        20.04        1.66
# 381  122.53        32.34        3.17
# 383  133.88        27.00        2.10
# 387   21.55        21.94        2.86
# 420 -116.69        25.00        2.10
# 422  -77.74        22.00        3.60
# 423  152.85        25.00        5.10
# 426  -65.76        16.11        1.34
# 435   -0.29        30.00        3.60
# 439   76.13         9.64        2.31
# 440   65.93        26.24        0.80
# 444   19.11         9.24        5.03
# 456  -68.33        19.14        1.97
# 459  150.85        23.33        7.70
# 463   57.06        15.00        1.00
# 483   46.17        21.00        2.10
# 492  102.79         8.64        1.84
# 493   67.00        22.64        0.35
# 503   39.83        29.44        3.53
# 504   55.19        11.14        7.26
# 507   32.90        28.00        2.60
# 512  112.52        30.04        2.31
# 520  132.26        32.00        4.10
# 524   62.22        17.00        0.84
# 529 -135.90         9.00        4.10
# 535 -100.44        33.00        4.60
# 541  166.46        27.00        6.20
# 549  113.28        21.34        9.92
#
# [92 rows x 9 columns]

# %%
chosen_pd.dropna()
# Out:
#                         City  Cloudiness Country        Date  Humidity    Lat  \
# 1                    Sarkand          99      KZ  1569548205        27  45.41
# 14                Tymovskoye           0      RU  1569548207        39  50.85
# 26   San Carlos de Bariloche           0      AR  1569548093        41 -41.13
# 30                 Jamestown           0      AU  1569548209        33 -33.21
# 34                     Yumen           0      CN  1569548210        10  40.29
# 40             Mar del Plata         100      AR  1569548211        43 -46.43
# 48                     Bluff           0      AU  1569548212        31 -23.58
# 51                  Cherskiy           3      RU  1569548213        39  68.75
# 54                  Karratha           0      AU  1569548213        15 -20.74
# 55                 Ilulissat           0      GL  1569548214        35  69.22
# 56               East London           0      ZA  1569548049        17 -33.02
# 59                Codrington           6      AU  1569548214        50 -28.95
# 60                    Nemuro          20      JP  1569548214        42  43.32
# 65                   Chifeng          32      CN  1569548215        21  42.27
# 66                     Kroya          57      ID  1569548215        33  -6.50
# 67       Santiago del Estero           0      AR  1569548216        36 -27.80
# 72                 Busselton          94      AU  1569547962        47 -33.64
# 77                    Harper           1      US  1569548217        45  30.30
# 89                   Birjand           0      IR  1569548219        13  32.86
# 90             West Wendover           1      US  1569548219        25  40.74
# 91                    Yulara           0      AU  1569548219        20 -25.24
# 94                 Carnarvon           0      ZA  1569548196        18 -30.97
# 107                Tucumcari           1      US  1569548222        30  35.17
# 113                    Airai           0      TL  1569548223        46  -8.93
# 133                    Arman           1      RU  1569548227        46  59.70
# 140        Riachao das Neves           3      BR  1569548224        30 -11.75
# 151                  Atwater          75      US  1569548229        40  37.35
# 160        Nerchinskiy Zavod           1      RU  1569548231        41  51.31
# 166                   Xining           0      CN  1569548232        42  36.62
# 176                     Muli           0      CN  1569548234        43  28.08
# ..                       ...         ...     ...         ...       ...    ...
# 352                  Atbasar         100      KZ  1569548263        50  51.81
# 353            Central Point           1      US  1569548263        32  42.38
# 358                 La Rioja           0      AR  1569548264        39 -29.41
# 380                     Bafq           0      IR  1569548268        12  31.60
# 381                   Katobu          70      ID  1569548268        44  -4.94
# 383            Alice Springs           0      AU  1569548268        26 -23.70
# 387                     Jalu           0      LY  1569548269        50  29.03
# 420                 Caldwell           1      US  1569548274        35  43.67
# 422                    Vardo           1      US  1569548275        49  39.62
# 423               Hervey Bay          40      AU  1569548275        47 -25.30
# 426                    Digby          33      CA  1569548275         1  44.62
# 435                    Adrar           0      DZ  1569548277         9  27.87
# 439                   Kargil           0      PK  1569548278        43  34.56
# 440                Sar-e Pul           0      AF  1569548278        18  36.22
# 456               San Rafael          82      AR  1569548281        32 -34.61
# 459                 Flinders           0      AU  1569548281        24 -34.58
# 463                   Kerman           0      IR  1569548282        14  30.29
# 483                   Mehran           0      IR  1569548285        28  33.12
# 492                   Madang           0      CN  1569548287        42  35.32
# 493                   Pishin           0      PK  1569548287        44  30.58
# 503                    Mecca           0      SA  1569548023        14  21.43
# 504                   Beyneu          93      KZ  1569548289        35  45.32
# 507                    Aswan           0      EG  1569548289        17  24.09
# 512               Xiangxiang          36      CN  1569548290        33  27.73
# 520                Katherine           0      AU  1569548291        31 -14.47
# 524                    Herat           0      AF  1569548292        23  34.35
# 529                     Mayo          75      CA  1569548293        36  63.59
# 535               San Angelo           1      US  1569548014        36  31.46
# 541                   Noumea          75      NC  1569548000        42 -22.28
# 549               Baruun-Urt          49      MN  1569548296        25  46.68
#
#         Lng  Max Temp(C)  Wind Speed
# 1     79.91        17.64        2.71
# 14   142.66        15.94        3.06
# 26   -71.31        15.00        2.10
# 30   138.60        21.84        6.71
# 34    97.04        24.14        2.91
# 40   -67.52        12.84        7.65
# 48   149.07        28.54        3.02
# 51   161.30         4.14        2.80
# 54   116.85        29.74        4.10
# 55   -51.10         4.00        4.60
# 56    27.91        18.14        2.24
# 59   153.24        27.00        4.10
# 60   145.57        19.00        0.50
# 65   118.96        21.94        3.35
# 66   108.06        34.24        3.68
# 67   -64.26        20.04        4.25
# 72   115.35        18.33        2.90
# 77   -99.24        29.00        6.05
# 89    59.22        21.00        6.20
# 90  -114.07        25.00        3.65
# 91   130.99        29.00        2.60
# 94    22.13        10.24        2.32
# 107 -103.73        27.00        4.60
# 113  125.41        30.24        2.42
# 133  150.17         3.44        3.17
# 140  -44.91        22.14        1.12
# 151 -120.61        30.00        5.70
# 160  119.61        18.24        5.04
# 166  101.77        20.00        2.37
# 176  109.56        26.84        1.32
# ..      ...          ...         ...
# 352   68.36         5.64        1.25
# 353 -122.91        28.00        4.10
# 358  -66.86        16.44        2.40
# 380   55.40        20.04        1.66
# 381  122.53        32.34        3.17
# 383  133.88        27.00        2.10
# 387   21.55        21.94        2.86
# 420 -116.69        25.00        2.10
# 422  -77.74        22.00        3.60
# 423  152.85        25.00        5.10
# 426  -65.76        16.11        1.34
# 435   -0.29        30.00        3.60
# 439   76.13         9.64        2.31
# 440   65.93        26.24        0.80
# 456  -68.33        19.14        1.97
# 459  150.85        23.33        7.70
# 463   57.06        15.00        1.00
# 483   46.17        21.00        2.10
# 492  102.79         8.64        1.84
# 493   67.00        22.64        0.35
# 503   39.83        29.44        3.53
# 504   55.19        11.14        7.26
# 507   32.90        28.00        2.60
# 512  112.52        30.04        2.31
# 520  132.26        32.00        4.10
# 524   62.22        17.00        0.84
# 529 -135.90         9.00        4.10
# 535 -100.44        33.00        4.60
# 541  166.46        27.00        6.20
# 549  113.28        21.34        9.92
#
# [87 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotels_df = chosen_pd[["City", "Country", "Lat", "Lng", "Humidity"]]
hotels_df.head()
# Out:
#                        City Country    Lat     Lng  Humidity
# 1                   Sarkand      KZ  45.41   79.91        27
# 14               Tymovskoye      RU  50.85  142.66        39
# 26  San Carlos de Bariloche      AR -41.13  -71.31        41
# 27             Grootfontein     NaN -19.56   18.10        33
# 30                Jamestown      AU -33.21  138.60        33

# %%
hotels_df["Hotel Name"]= ""
hotels_df.head()
# Out:
# /Users/Deborah/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        City Country    Lat     Lng  Humidity Hotel Name
# 1                   Sarkand      KZ  45.41   79.91        27
# 14               Tymovskoye      RU  50.85  142.66        39
# 26  San Carlos de Bariloche      AR -41.13  -71.31        41
# 27             Grootfontein     NaN -19.56   18.10        33
# 30                Jamestown      AU -33.21  138.60        33

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#print(requests.get(base_url).json())
params = {"radius": 5000,
            "type": "hotels",
         "key": g_key}
hotel_names = []
for index, row in hotels_df.iterrows():
    params["location"]= f'{row["Lat"]},{row["Lng"]}'
    response = requests.get(base_url, params =params).json()
    
    results = response["results"]
print(results)
    #hotel_names.append(response["results"][0]["name"])
#print(hotel_names)
# Out:
# [{'geometry': {'location': {'lat': 46.6652838, 'lng': 113.2876804}, 'viewport': {'northeast': {'lat': 46.6986114, 'lng': 113.3168507}, 'southwest': {'lat': 46.6387118, 'lng': 113.2545376}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png', 'id': 'a14539fa767ae18d239e3b677e1804bcad24131a', 'name': 'Baruun-Urt', 'place_id': 'ChIJ76UDTpLz5l0RwapxogwRSLw', 'reference': 'ChIJ76UDTpLz5l0RwapxogwRSLw', 'scope': 'GOOGLE', 'types': ['locality', 'political'], 'vicinity': 'Baruun-Urt'}, {'geometry': {'location': {'lat': 46.68399609999999, 'lng': 113.2815796}, 'viewport': {'northeast': {'lat': 46.68518958029149, 'lng': 113.2830152802915}, 'southwest': {'lat': 46.6824916197085, 'lng': 113.2803173197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '4798bc52ee97cbe7d926ae54925bec1a45f6f748', 'name': 'Хүнсний Дэлгүүр', 'place_id': 'ChIJ7S8bce3z5l0Rczc2l7w1BQA', 'plus_code': {'compound_code': 'M7MJ+HJ Baruun-Urt, Mongolia', 'global_code': '8PRMM7MJ+HJ'}, 'reference': 'ChIJ7S8bce3z5l0Rczc2l7w1BQA', 'scope': 'GOOGLE', 'types': ['convenience_store', 'food', 'point_of_interest', 'store', 'establishment'], 'vicinity': 'Baruun-Urt'}, {'geometry': {'location': {'lat': 46.6802293, 'lng': 113.2777575}, 'viewport': {'northeast': {'lat': 46.6813077302915, 'lng': 113.2791355302915}, 'southwest': {'lat': 46.6786097697085, 'lng': 113.2764375697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'a63ca93fa9808d63b36c5ea04137e259f6e5f289', 'name': 'Jaakhan Sharga theatre', 'place_id': 'ChIJCxlzh5Lz5l0RemHdPSsNFDc', 'plus_code': {'compound_code': 'M7JH+34 Baruun-Urt, Mongolia', 'global_code': '8PRMM7JH+34'}, 'rating': 5, 'reference': 'ChIJCxlzh5Lz5l0RemHdPSsNFDc', 'scope': 'GOOGLE', 'types': ['point_of_interest', 'establishment'], 'user_ratings_total': 1, 'vicinity': 'Baruun-Urt - Tumentsogt Road, Baruun-Urt'}, {'geometry': {'location': {'lat': 46.6815328, 'lng': 113.270601}, 'viewport': {'northeast': {'lat': 46.6832264302915, 'lng': 113.2718878302915}, 'southwest': {'lat': 46.6805284697085, 'lng': 113.2691898697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'fbb7f9f0760545e52d642f0c9d65b7589a3a6e6d', 'name': '"Цайрт" хотхон', 'photos': [{'height': 1365, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101424567973273343720/photos">Bulgaa Erdene</a>'], 'photo_reference': 'CmRaAAAAqv49LIwbQmIduVsyoOqAHQVqO9JBqury5WjUb8ssukzJQ3Z1IYkNLeDNStkHBtamHiB4OE1HASQFz-_VfN6YHJVpegR_gp3tUkDCyRD6lsEOocY-tH5DzPt-9PvswHyIEhCTIJ8f2H0f_OQoYgCDMVeXGhS8iJ8BTK7jrO2PGL9ll84Jouge3g', 'width': 2048}], 'place_id': 'ChIJbR1jfozz5l0Rdh6EAW3P3tY', 'plus_code': {'compound_code': 'M7JC+J6 Baruun-Urt, Mongolia', 'global_code': '8PRMM7JC+J6'}, 'rating': 5, 'reference': 'ChIJbR1jfozz5l0Rdh6EAW3P3tY', 'scope': 'GOOGLE', 'types': ['point_of_interest', 'establishment'], 'user_ratings_total': 2, 'vicinity': 'Mongolia'}, {'geometry': {'location': {'lat': 46.6867343, 'lng': 113.2783498}, 'viewport': {'northeast': {'lat': 46.6879782302915, 'lng': 113.2797760802915}, 'southwest': {'lat': 46.6852802697085, 'lng': 113.2770781197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png', 'id': '77213cebf178be3ac0846cddb9f4573c8f3a1278', 'name': 'Сүхбаатар аймаг 2-р сургууль', 'place_id': 'ChIJQz8JzPPz5l0RsNFxPrMswss', 'plus_code': {'compound_code': 'M7PH+M8 Baruun-Urt, Mongolia', 'global_code': '8PRMM7PH+M8'}, 'rating': 5, 'reference': 'ChIJQz8JzPPz5l0RsNFxPrMswss', 'scope': 'GOOGLE', 'types': ['school', 'point_of_interest', 'establishment'], 'user_ratings_total': 1, 'vicinity': 'Baruun-Urt'}, {'geometry': {'location': {'lat': 46.6652838, 'lng': 113.2876804}, 'viewport': {'northeast': {'lat': 46.6666327802915, 'lng': 113.2890293802915}, 'southwest': {'lat': 46.6639348197085, 'lng': 113.2863314197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': 'c3dd2890 ...

# %%
hotels_df.loc[index, "Hotel Name"] = results[0]['name']
hotels_df.head(10)
# Out:
#                        City Country    Lat     Lng  Humidity Hotel Name
# 1                   Sarkand      KZ  45.41   79.91        27
# 14               Tymovskoye      RU  50.85  142.66        39
# 26  San Carlos de Bariloche      AR -41.13  -71.31        41
# 27             Grootfontein     NaN -19.56   18.10        33
# 30                Jamestown      AU -33.21  138.60        33
# 34                    Yumen      CN  40.29   97.04        10
# 40            Mar del Plata      AR -46.43  -67.52        43
# 48                    Bluff      AU -23.58  149.07        31
# 51                 Cherskiy      RU  68.75  161.30        39
# 54                 Karratha      AU -20.74  116.85        15

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotels_df.iterrows()]
#hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotels_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

#new_york_coordinates = (40.75, -74.00)
#fig = gmaps.figure(center=new_york_coordinates, zoom_level=2)
#heat_layer = gmaps.heatmap_layer(locations, weights="Humidity", dissipating=False, max_intensity=10, point_radius=2)

#Add layer
##fig.add_layer(heat_layer)
#fig

figure_layout = {'width': '400px',
                'height': '300px',
                'border': '1px solid black',
                'padding': '1px',
                'margin': '0 auto 0 auto'}
fig =gmaps.figure(layout=figure_layout)
markers =gmaps.marker_layer(locations)
fig.add_layer(markers)
# Display Map
fig

#fig =gmaps.figure()
#fig.add_layer(heat-layer)
#fig.add_layers(markers)
#fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
